# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Needed imports

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn import neighbors
import datetime
import math

# Keras specific
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

def add_index(row):
  return int(row.name)
wd = "/content/drive/MyDrive/DamsoPronos-TNF/"

# %% [markdown]
# # Setup + Training

# %%
pays = "E0"
xg = False

# %% [markdown]
# ## elo set **up** (1st year)

# %%
#set up elo on year 2017
data17 = pd.read_csv(wd+'datasets/'+pays+'_17.csv')[['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'HS', 'AS', 'HST', 'AST', 'B365H', 'B365D', 'B365A']]
elo = {}
for team in data17['HomeTeam'].unique():
  elo[team]=1000
data17["eloHome"]=0
data17["eloAway"]=0
eloK = 10
for index, row in data17.iterrows():
  rh = elo[row["HomeTeam"]]
  ra = elo[row['AwayTeam']]
  Rh = 10**(rh/400)
  Ra = 10**(ra/400)
  Eh = Rh/(Rh+Ra)
  Ea = 1-Eh
  if row["FTHG"]>row["FTAG"]:
    Sh=1
    Sa=0
  elif row["FTAG"]>row["FTHG"]:
    Sh=0
    Sa=1
  else:
    Sh=0.5
    Sa=0.5
  nrh = rh + eloK*(Sh-Eh)
  nra = ra + eloK*(Sa-Ea)
  elo[row["HomeTeam"]]= round(nrh)
  elo[row["AwayTeam"]]= round(nra)

print(sorted( ((v,k) for k,v in elo.items()), reverse=True))
# Out:
# [(1112, 'Man City'), (1072, 'Man United'), (1063, 'Tottenham'), (1062, 'Liverpool'), (1037, 'Chelsea'), (1020, 'Arsenal'), (1004, 'Burnley'), (995, 'Everton'), (988, 'Leicester'), (987, 'Crystal Palace'), (983, 'Bournemouth'), (980, 'West Ham'), (979, 'Newcastle'), (974, 'Brighton'), (967, 'Southampton'), (965, 'Watford'), (959, 'Huddersfield'), (953, 'West Brom'), (952, 'Stoke'), (948, 'Swansea')]

# %%
#set up elo on year 2017
data18 = pd.read_csv(wd+'datasets/'+pays+'_18.csv')[['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'HS', 'AS', 'HST', 'AST', 'B365H', 'B365D', 'B365A']]
for team in data18['HomeTeam'].unique():
    if not(team in elo.keys()):
      elo[team]=1000
for index, row in data17.iterrows():
  rh = elo[row["HomeTeam"]]
  ra = elo[row['AwayTeam']]
  Rh = 10**(rh/400)
  Ra = 10**(ra/400)
  Eh = Rh/(Rh+Ra)
  Ea = 1-Eh
  if row["FTHG"]>row["FTAG"]:
    Sh=1
    Sa=0
  elif row["FTAG"]>row["FTHG"]:
    Sh=0
    Sa=1
  else:
    Sh=0.5
    Sa=0.5
  nrh = rh + eloK*(Sh-Eh)
  nra = ra + eloK*(Sa-Ea)
  elo[row["HomeTeam"]]= round(nrh)
  elo[row["AwayTeam"]]= round(nra)

print(sorted( ((v,k) for k,v in elo.items()), reverse=True))
# Out:
# [(1179, 'Man City'), (1112, 'Man United'), (1097, 'Tottenham'), (1096, 'Liverpool'), (1062, 'Chelsea'), (1034, 'Arsenal'), (1004, 'Burnley'), (1000, 'Wolves'), (1000, 'Fulham'), (1000, 'Cardiff'), (989, 'Everton'), (981, 'Crystal Palace'), (979, 'Leicester'), (977, 'Bournemouth'), (971, 'West Ham'), (967, 'Newcastle'), (960, 'Brighton'), (947, 'Watford'), (947, 'Southampton'), (933, 'Huddersfield'), (924, 'Stoke'), (923, 'West Brom'), (918, 'Swansea')]

# %% [markdown]
# ## prepare data

# %%
data18 = pd.read_csv(wd+'datasets/'+pays+'_18.csv')[['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'HS', 'AS', 'HST', 'AST', 'B365H', 'B365D', 'B365A']]
xg18 = pd.read_csv(wd+'/datasets/'+pays+'18xG.csv')[['Squad', 'xG']]
def add_index(row):
  return int(row.name)

data18["index"]=data18.apply(add_index, axis=1)

def custom_hs(row):
  value = data18.loc[(data18['HomeTeam'] == row['HomeTeam'])].loc[data18['index']<int(row.name)]['HS'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_as(row):
  value = data18.loc[(data18['AwayTeam'] == row['AwayTeam'])].loc[data18['index']<int(row.name)]['AS'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_hst(row):
  value = data18.loc[(data18['HomeTeam'] == row['HomeTeam'])].loc[data18['index']<int(row.name)]['HST'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_ast(row):
  value = data18.loc[(data18['AwayTeam'] == row['AwayTeam'])].loc[data18['index']<int(row.name)]['AST'].mean()
  if math.isnan(value):
    return 0
  return value


def custom_hc(row):
  value = data18.loc[(data18['HomeTeam'] == row['HomeTeam'])].loc[data18['index']<int(row.name)]['HC'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_ac(row):
  value = data18.loc[(data18['AwayTeam'] == row['AwayTeam'])].loc[data18['index']<int(row.name)]['AC'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_psdg(row):
  pshg = data18.loc[(data18['HomeTeam'] == row['HomeTeam'])].loc[data18['index']<int(row.name)]['FTHG'].sum()
  psag = data18.loc[(data18['AwayTeam'] == row['AwayTeam'])].loc[data18['index']<int(row.name)]['FTAG'].sum()
  if math.isnan(pshg-psag):
    return 0
  return pshg-psag

def xhg18(row):
  return xg18.loc[xg18['Squad']==row["HomeTeam"]]["xG"].mean()

def xag18(row):
  return xg18.loc[xg18['Squad']==row["AwayTeam"]]["xG"].mean()
if xg:
  data18['xHG'] = data18.apply(xhg18, axis=1)
  data18['xAG'] = data18.apply(xag18, axis=1)
data18['CustomHS']=data18.apply(custom_hs, axis=1)
data18['CustomAS']=data18.apply(custom_as, axis=1)
data18['CustomHST']=data18.apply(custom_hst, axis=1)
data18['CustomAST']=data18.apply(custom_ast, axis=1)
data18['CustomPSDG']=data18.apply(custom_psdg, axis=1)

# %%
data18.tail(10)
# Out:
#     Div        Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 370  E0  12/05/2019        Brighton      Man City     1     4   A     1     2
# 371  E0  12/05/2019         Burnley       Arsenal     1     3   A     0     0
# 372  E0  12/05/2019  Crystal Palace   Bournemouth     5     3   H     3     1
# 373  E0  12/05/2019          Fulham     Newcastle     0     4   A     0     2
# 374  E0  12/05/2019       Leicester       Chelsea     0     0   D     0     0
# 375  E0  12/05/2019       Liverpool        Wolves     2     0   H     1     0
# 376  E0  12/05/2019      Man United       Cardiff     0     2   A     0     1
# 377  E0  12/05/2019     Southampton  Huddersfield     1     1   D     1     0
# 378  E0  12/05/2019       Tottenham       Everton     2     2   D     1     0
# 379  E0  12/05/2019         Watford      West Ham     1     4   A     0     2
#
#     HTR  ...  AST  B365H  B365D  B365A  index   CustomHS   CustomAS  \
# 370   A  ...    9  19.00   8.50   1.16    370  10.777778  15.388889
# 371   D  ...    6   3.25   3.80   2.20    371  10.888889  10.722222
# 372   H  ...    8   1.90   4.20   3.80    372  15.388889  11.222222
# 373   A  ...    6   2.50   3.60   2.90    373  14.333333   9.166667
# 374   D  ...    4   2.40   3.75   2.90    374  16.055556  14.833333
# 375   H  ...    2   1.30   6.00  11.00    375  17.888889  11.111111
# 376   A  ...    4   1.28   6.50  11.00    376  14.333333   9.666667
# 377   H  ...    3   1.44   4.75   8.50    377  13.777778  10.388889
# 378   H  ...    9   2.20   3.50   3.50    378  16.500000  11.055556
# 379   A  ...    9   2.25   3.75   3.20    379  11.500000  10.000000
#
#      CustomHST  CustomAST  CustomPSDG
# 370   2.833333   5.722222         -16
# 371   3.388889   3.777778          -5
# 372   3.777778   4.055556          -9
# 373   4.666667   3.111111           8
# 374   5.333333   4.222222           0
# 375   6.722222   3.555556          34
# 376   6.444444   3.000000          22
# 377   4.777778   3.222222          15
# 378   5.666667   4.166667          10
# 379   4.166667   3.333333           9
#
# [10 rows x 23 columns]

# %%
data19 = pd.read_csv(wd+'/datasets/'+pays+'_19.csv')
xg19 = pd.read_csv(wd+'/datasets/'+pays+'19xG.csv')[['Squad', 'xG']]

common_cols = list(set.intersection(*(set(df.columns) for df in [data18, data19])))
data19=data19[common_cols]
data19["index"]=data19.apply(add_index, axis=1)

def custom_hs19(row):
  value = data19.loc[(data19['HomeTeam'] == row['HomeTeam'])].loc[data19['index']<int(row.name)]['HS'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_as19(row):
  value = data19.loc[(data19['AwayTeam'] == row['AwayTeam'])].loc[data19['index']<int(row.name)]['AS'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_hst19(row):
  value = data19.loc[(data19['HomeTeam'] == row['HomeTeam'])].loc[data19['index']<int(row.name)]['HST'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_ast19(row):
  value = data19.loc[(data19['AwayTeam'] == row['AwayTeam'])].loc[data19['index']<int(row.name)]['AST'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_hc19(row):
  value = data19.loc[(data19['HomeTeam'] == row['HomeTeam'])].loc[data19['index']<int(row.name)]['HC'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_ac19(row):
  value = data19.loc[(data19['AwayTeam'] == row['AwayTeam'])].loc[data19['index']<int(row.name)]['AC'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_psdg19(row):
  pshg = data19.loc[(data19['HomeTeam'] == row['HomeTeam'])].loc[data19['index']<int(row.name)]['FTHG'].sum()
  psag = data19.loc[(data19['AwayTeam'] == row['AwayTeam'])].loc[data19['index']<int(row.name)]['FTAG'].sum()
  if math.isnan(pshg-psag):
    return 0
  return pshg-psag

def custom_hf19(row):
  value = data19.loc[(data19['AwayTeam'] == row['AwayTeam'])].loc[data19['index']<int(row.name)]['HF'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_af19(row):
  value = data19.loc[(data19['AwayTeam'] == row['AwayTeam'])].loc[data19['index']<int(row.name)]['AF'].mean()
  if math.isnan(value):
    return 0
  return value

def xhg19(row):
  return xg19.loc[xg19['Squad']==row["HomeTeam"]]["xG"].mean()

def xag19(row):
  return xg19.loc[xg19['Squad']==row["AwayTeam"]]["xG"].mean()

if xg:
  data19['xHG'] = data19.apply(xhg19, axis=1)
  data19['xAG'] = data19.apply(xag19, axis=1)
data19['CustomHS']=data19.apply(custom_hs19, axis=1)
data19['CustomAS']=data19.apply(custom_as19, axis=1)
data19['CustomHST']=data19.apply(custom_hst19, axis=1)
data19['CustomAST']=data19.apply(custom_ast19, axis=1)
data19['CustomPSDG']=data19.apply(custom_psdg19, axis=1)

# %%
data19.tail(10)
# Out:
#            Date  AST  FTHG        HomeTeam  HTHG FTR  FTAG  B365D  HST  HTAG  \
# 370  26/07/2020    6     3         Arsenal     3   H     2   3.80    5     1
# 371  26/07/2020    4     1         Burnley     1   A     2   3.40    2     1
# 372  26/07/2020    1     2         Chelsea     2   H     0   3.80    3     0
# 373  26/07/2020    2     1  Crystal Palace     0   D     1   4.20    2     1
# 374  26/07/2020    7     1         Everton     1   A     3   3.70    5     2
# 375  26/07/2020    3     0       Leicester     0   A     2   3.50    3     0
# 376  26/07/2020    4     5        Man City     2   H     0  11.00   10     0
# 377  26/07/2020    6     1       Newcastle     1   A     3   5.25    2     1
# 378  26/07/2020    3     3     Southampton     0   H     1   3.50    4     1
# 379  26/07/2020    4     1        West Ham     0   D     1   3.60    1     0
#
#      ...          AwayTeam  Div  B365A HTR index   CustomHS   CustomAS  \
# 370  ...           Watford   E0   3.80   H   370  12.111111   8.944444
# 371  ...          Brighton   E0   3.00   D   371  11.500000  11.722222
# 372  ...            Wolves   E0   4.00   H   372  17.833333  12.222222
# 373  ...         Tottenham   E0   1.55   A   373  12.111111  10.666667
# 374  ...       Bournemouth   E0   3.00   A   374  13.277778   9.833333
# 375  ...        Man United   E0   2.20   D   375  13.777778  13.166667
# 376  ...           Norwich   E0  26.00   H   376  20.166667  10.333333
# 377  ...         Liverpool   E0   1.36   D   377  12.777778  14.555556
# 378  ...  Sheffield United   E0   3.30   A   378  12.611111   7.777778
# 379  ...       Aston Villa   E0   2.30   D   379  11.722222  10.944444
#
#      CustomHST  CustomAST  CustomPSDG
# 370   4.777778   2.888889          21
# 371   4.388889   3.888889           6
# 372   6.555556   4.055556           4
# 373   3.666667   4.388889         -10
# 374   4.888889   2.944444           8
# 375   4.722222   5.277778          11
# 376   6.944444   3.000000          45
# 377   4.166667   5.333333         -11
# 378   4.055556   2.333333           4
# 379   4.888889   3.666667          11
#
# [10 rows x 23 columns]

# %%
data20= pd.read_csv(wd+'/datasets/'+pays+'_20.csv')[common_cols]
xg20 = pd.read_csv(wd+'/datasets/'+pays+'20xG.csv')[['Squad', 'xG']]
data20["index"]=data20.apply(add_index, axis=1)
def custom_hs20(row):
  value = data20.loc[(data20['HomeTeam'] == row['HomeTeam'])].loc[data20['index']<int(row.name)]['HS'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_as20(row):
  value = data20.loc[(data20['AwayTeam'] == row['AwayTeam'])].loc[data20['index']<int(row.name)]['AS'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_hst20(row):
  value = data20.loc[(data20['HomeTeam'] == row['HomeTeam'])].loc[data20['index']<int(row.name)]['HST'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_ast20(row):
  value = data20.loc[(data20['AwayTeam'] == row['AwayTeam'])].loc[data20['index']<int(row.name)]['AST'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_hc20(row):
  value = data20.loc[(data20['HomeTeam'] == row['HomeTeam'])].loc[data20['index']<int(row.name)]['HC'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_ac20(row):
  value = data20.loc[(data20['AwayTeam'] == row['AwayTeam'])].loc[data20['index']<int(row.name)]['AC'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_psdg20(row):
  pshg = data20.loc[(data20['HomeTeam'] == row['HomeTeam'])].loc[data20['index']<int(row.name)]['FTHG'].sum()
  psag = data20.loc[(data20['AwayTeam'] == row['AwayTeam'])].loc[data20['index']<int(row.name)]['FTAG'].sum()
  if math.isnan(pshg-psag):
    return 0
  return pshg-psag

def custom_hf20(row):
  value = data20.loc[(data20['AwayTeam'] == row['AwayTeam'])].loc[data20['index']<int(row.name)]['HF'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_af20(row):
  value = data20.loc[(data20['AwayTeam'] == row['AwayTeam'])].loc[data20['index']<int(row.name)]['AF'].mean()
  if math.isnan(value):
    return 0
  return value

def xhg20(row):
  return xg20.loc[xg20['Squad']==row["HomeTeam"]]["xG"].mean()

def xag20(row):
  return xg20.loc[xg20['Squad']==row["AwayTeam"]]["xG"].mean()

if xg:
  data20['xHG'] = data20.apply(xhg20, axis=1)
  data20['xAG'] = data20.apply(xag20, axis=1)
data20['CustomHS']=data20.apply(custom_hs20, axis=1)
data20['CustomAS']=data20.apply(custom_as20, axis=1)
data20['CustomHST']=data20.apply(custom_hst20, axis=1)
data20['CustomAST']=data20.apply(custom_ast20, axis=1)
data20['CustomPSDG']=data20.apply(custom_psdg20, axis=1)

# %%
data20.tail(10)
# Out:
#            Date  AST  FTHG          HomeTeam  HTHG FTR  FTAG  B365D  HST  \
# 370  23/05/2021    1     2           Arsenal     0   H     0   4.33    5
# 371  23/05/2021    7     2       Aston Villa     1   H     1   4.60    3
# 372  23/05/2021    4     0            Fulham     0   A     2   3.80    0
# 373  23/05/2021    5     3             Leeds     2   H     1   5.25    9
# 374  23/05/2021    4     2         Leicester     1   A     4   4.00    6
# 375  23/05/2021    4     2         Liverpool     1   H     0   8.50    5
# 376  23/05/2021    3     5          Man City     2   H     0   5.00   11
# 377  23/05/2021    3     1  Sheffield United     1   H     0   3.60    3
# 378  23/05/2021    5     3          West Ham     2   H     0   4.00    7
# 379  23/05/2021    4     1            Wolves     1   A     2   3.50    4
#
#      HTAG  ...        AwayTeam  Div  B365A HTR index   CustomHS   CustomAS  \
# 370     0  ...        Brighton   E0   5.25   D   370  12.444444  10.388889
# 371     0  ...         Chelsea   E0   1.45   H   371  14.611111  14.000000
# 372     1  ...       Newcastle   E0   3.30   A   372  12.222222   8.611111
# 373     0  ...       West Brom   E0   6.50   H   373  13.777778   8.444444
# 374     1  ...       Tottenham   E0   3.30   D   374  13.000000  11.055556
# 375     0  ...  Crystal Palace   E0  15.00   H   375  16.555556  10.111111
# 376     0  ...         Everton   E0   6.50   H   376  17.055556   9.666667
# 377     0  ...         Burnley   E0   2.40   H   377   9.611111   9.833333
# 378     0  ...     Southampton   E0   5.00   H   378  11.444444   9.888889
# 379     2  ...      Man United   E0   2.70   A   379  14.222222  13.166667
#
#      CustomHST  CustomAST  CustomPSDG
# 370   4.000000   3.444444           4
# 371   5.111111   5.000000           1
# 372   3.500000   3.277778          -9
# 373   5.444444   2.666667           6
# 374   4.888889   3.833333           3
# 375   5.777778   3.722222           6
# 376   6.055556   3.833333          15
# 377   3.111111   3.555556          -8
# 378   4.111111   3.722222          10
# 379   4.722222   5.611111         -13
#
# [10 rows x 23 columns]

# %%
data21 = pd.read_csv(wd+'datasets/'+pays+'_21.csv')[['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'HS', 'AS', 'HST', 'AST', 'B365H', 'B365D', 'B365A']]
xg21 = pd.read_csv(wd+'/datasets/'+pays+'21xG.csv')[['Squad', 'xG']]
def add_index(row):
  return int(row.name)

data21["index"]=data21.apply(add_index, axis=1)

def custom_hs(row):
  value = data21.loc[(data21['HomeTeam'] == row['HomeTeam'])].loc[data21['index']<int(row.name)]['HS'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_as(row):
  value = data21.loc[(data21['AwayTeam'] == row['AwayTeam'])].loc[data21['index']<int(row.name)]['AS'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_hst(row):
  value = data21.loc[(data21['HomeTeam'] == row['HomeTeam'])].loc[data21['index']<int(row.name)]['HST'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_ast(row):
  value = data21.loc[(data21['AwayTeam'] == row['AwayTeam'])].loc[data21['index']<int(row.name)]['AST'].mean()
  if math.isnan(value):
    return 0
  return value


def custom_hc(row):
  value = data21.loc[(data21['HomeTeam'] == row['HomeTeam'])].loc[data21['index']<int(row.name)]['HC'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_ac(row):
  value = data21.loc[(data21['AwayTeam'] == row['AwayTeam'])].loc[data21['index']<int(row.name)]['AC'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_psdg(row):
  pshg = data21.loc[(data21['HomeTeam'] == row['HomeTeam'])].loc[data21['index']<int(row.name)]['FTHG'].sum()
  psag = data21.loc[(data21['AwayTeam'] == row['AwayTeam'])].loc[data21['index']<int(row.name)]['FTAG'].sum()
  if math.isnan(pshg-psag):
    return 0
  return pshg-psag

def xhg21(row):
  return xg21.loc[xg21['Squad']==row["HomeTeam"]]["xG"].mean()

def xag21(row):
  return xg21.loc[xg21['Squad']==row["AwayTeam"]]["xG"].mean()

if xg:
  data21['xHG'] = data21.apply(xhg21, axis=1)
  data21['xAG'] = data21.apply(xag21, axis=1)
data21['CustomHS']=data21.apply(custom_hs, axis=1)
data21['CustomAS']=data21.apply(custom_as, axis=1)
data21['CustomHST']=data21.apply(custom_hst, axis=1)
data21['CustomAST']=data21.apply(custom_ast, axis=1)
data21['CustomPSDG']=data21.apply(custom_psdg, axis=1)

# %%
data = data19.append(data20).append(data21)
data.reset_index(drop=True, inplace=True)
data
# Out:
#             Date  AST  FTHG        HomeTeam  HTHG FTR  FTAG  B365D  HST  HTAG  \
# 0     09/08/2019    5     4       Liverpool     4   H     1  10.00    7     0
# 1     10/08/2019    9     0        West Ham     0   A     5   6.50    3     1
# 2     10/08/2019    3     1     Bournemouth     0   D     1   3.60    3     0
# 3     10/08/2019    3     3         Burnley     0   H     0   3.20    4     0
# 4     10/08/2019    3     0  Crystal Palace     0   D     0   3.25    2     0
# ...          ...  ...   ...             ...   ...  ..   ...    ...  ...   ...
# 1135  22/05/2022    4     1  Crystal Palace     1   H     0   3.60    3     0
# 1136  22/05/2022    2     4       Leicester     0   H     1   4.00    6     0
# 1137  22/05/2022    5     3       Liverpool     1   H     1   8.50    8     1
# 1138  22/05/2022    2     3        Man City     0   H     2   8.00    5     1
# 1139  22/05/2022   13     0         Norwich     0   A     5   6.50    0     2
#
#       ...          AwayTeam  Div  B365A HTR index   CustomHS   CustomAS  \
# 0     ...           Norwich   E0  19.00   H     0   0.000000   0.000000
# 1     ...          Man City   E0   1.22   A     1   0.000000   0.000000
# 2     ...  Sheffield United   E0   3.60   D     2   0.000000   0.000000
# 3     ...       Southampton   E0   2.75   D     3   0.000000   0.000000
# 4     ...           Everton   E0   2.37   D     4   0.000000   0.000000
# ...   ...               ...  ...    ...  ..   ...        ...        ...
# 1135  ...        Man United   E0   2.25   H   375  12.500000  12.166667
# 1136  ...       Southampton   E0   3.80   D   376  12.500000  13.277778
# 1137  ...            Wolves   E0  15.00   D   377  20.833333   9.555556
# 1138  ...       Aston Villa   E0  17.00   A   378  18.722222  11.944444
# 1139  ...         Tottenham   E0   1.25   A   379  10.777778  11.777778
#
#       CustomHST  CustomAST  CustomPSDG
# 0      0.000000   0.000000           0
# 1      0.000000   0.000000           0
# 2      0.000000   0.000000           0
# 3      0.000000   0.000000           0
# 4      0.000000   0.000000           0
# ...         ...        ...         ...
# 1135   4.333333   4.611111           1
# 1136   4.888889   4.500000          11
# 1137   7.111111   3.333333          29
# 1138   7.111111   4.111111          34
# 1139   3.500000   4.888889         -14
#
# [1140 rows x 23 columns]

# %% [markdown]
# ## apply elo

# %%
elo
# Out:
# {'Arsenal': 1034,
#  'Brighton': 960,
#  'Chelsea': 1062,
#  'Crystal Palace': 981,
#  'Everton': 989,
#  'Southampton': 947,
#  'Watford': 947,
#  'West Brom': 923,
#  'Man United': 1112,
#  'Newcastle': 967,
#  'Bournemouth': 977,
#  'Burnley': 1004,
#  'Leicester': 979,
#  'Liverpool': 1096,
#  'Stoke': 924,
#  'Swansea': 918,
#  'Huddersfield': 933,
#  'Tottenham': 1097,
#  'Man City': 1179,
#  'West Ham': 971,
#  'Fulham': 1000,
#  'Wolves': 1000,
#  'Cardiff': 1000}

# %%
for team in data['HomeTeam'].unique():
  if not(team in elo.keys()):
    elo[team]=800
for index, row in data.iterrows():
  rh = elo[row["HomeTeam"]]
  ra = elo[row['AwayTeam']]
  Rh = 10**(rh/400)
  Ra = 10**(ra/400)
  Eh = Rh/(Rh+Ra)
  Ea = 1-Eh
  if row["FTHG"]>row["FTAG"]:
    Sh=1
    Sa=0
  elif row["FTAG"]>row["FTHG"]:
    Sh=0
    Sa=1
  else:
    Sh=0.5
    Sa=0.5
  nrh = int(round(rh + eloK*(Sh-Eh)))
  nra = int(round(ra + eloK*(Sa-Ea)))
  elo[row["HomeTeam"]]= nrh
  elo[row["AwayTeam"]]= nra
  data.loc[index,['eloHome']] = rh
  data.loc[index, ['eloAway']] = ra

print(sorted( ((v,k) for k,v in elo.items()), reverse=True))
# Out:
# [(1209, 'Man City'), (1179, 'Liverpool'), (1089, 'Chelsea'), (1073, 'Man United'), (1071, 'Tottenham'), (1050, 'Arsenal'), (1005, 'Leicester'), (1000, 'Cardiff'), (992, 'West Ham'), (973, 'Wolves'), (967, 'Brighton'), (966, 'Newcastle'), (957, 'Crystal Palace'), (950, 'Everton'), (937, 'Fulham'), (933, 'Huddersfield'), (931, 'Burnley'), (929, 'Bournemouth'), (927, 'Southampton'), (924, 'Stoke'), (918, 'Swansea'), (911, 'Aston Villa'), (898, 'Leeds'), (885, 'West Brom'), (855, 'Watford'), (854, 'Brentford'), (843, 'Sheffield United'), (774, 'Norwich')]

# %%
def home_or_dc(row):
    if row['FTR'] == 'H':
        val = 0
    else:
        val = 1
    return val

def exact_pred(row):
    if row['FTR'] == 'H':
        val = 0
    elif row['FTR'] == 'D':
        val = 1
    else:
        val = 2
    return val

data['FTR2']=data.apply(home_or_dc, axis=1)
data['FTR3']=data.apply(exact_pred, axis=1)
data = data.dropna()
print(data.shape)
normalized_df=(data-data.mean())/data.std()
# Out:
# (1140, 27)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
provided_columns= ['B365H', 'B365D', 'B365A', 'HS', 'AS', 'HST', 'AST', 'CustomPSDG']

real_columns=['B365H', 'B365D', 'B365A', 'CustomHS', 'CustomAS', 'CustomHST', 'CustomAST', 'CustomPSDG', 'eloHome', 'eloAway']

# x = data[real_columns]
# y = data['FTR2'].values
x = normalized_df[real_columns]
y = data['FTR2'].values
xtrain, xtest, ytrain, ytest = train_test_split(x, y, train_size=0.9)

print(x.shape, len(y))
# Out:
# (1140, 10) 1140

# %%
x
# Out:
#          B365H     B365D     B365A  CustomHS  CustomAS  CustomHST  CustomAST  \
# 0    -0.830835  4.222908  3.642199 -2.948071 -2.828365  -2.667372  -2.435888
# 1     3.992598  1.666676 -0.831710 -2.948071 -2.828365  -2.667372  -2.435888
# 2    -0.471076 -0.451345 -0.232840 -2.948071 -2.828365  -2.667372  -2.435888
# 3    -0.173498 -0.743485 -0.446722 -2.948071 -2.828365  -2.667372  -2.435888
# 4    -0.004722 -0.706968 -0.542340 -2.948071 -2.828365  -2.667372  -2.435888
# ...        ...       ...       ...       ...       ...        ...        ...
# 1135 -0.004722 -0.451345 -0.572535 -0.053395  0.335214   0.004731   0.438291
# 1136 -0.515491 -0.159204 -0.182515 -0.053395  0.624126   0.347308   0.369033
# 1137 -0.830835  3.127380  2.635695  1.876388 -0.343727   1.717618  -0.358168
# 1138 -0.821952  2.762204  3.138947  1.387510  0.277432   1.717618   0.126633
# 1139  2.882232  1.666676 -0.824161 -0.452217  0.234095  -0.509135   0.611434
#
#       CustomPSDG   eloHome   eloAway
# 0      -0.174436  1.147309 -1.924025
# 1      -0.174436 -0.148731  2.001062
# 2      -0.174436 -0.086521 -1.924025
# 3      -0.174436  0.193424 -0.401630
# 4      -0.174436 -0.045048  0.033340
# ...          ...       ...       ...
# 1135   -0.049526 -0.366465  0.975776
# 1136    1.199577  0.162319 -0.567332
# 1137    3.447961  1.987143 -0.111650
# 1138    4.072513  2.298192 -0.753748
# 1139   -1.923180 -2.170553  0.861855
#
# [1140 rows x 10 columns]

# %% [markdown]
# ## keras classification

# %%
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

# %%
keras.backend.clear_session()
model = Sequential()

i = Input(shape=(10,))

model.add(i)
model.add(Dense(500, activation='relu'))
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(250, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(20, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='relu'))
# Compile the model
model.compile(optimizer=Adam(lr=0.001), 
              loss="binary_crossentropy", 
              metrics=['accuracy'])
es_callback = keras.callbacks.EarlyStopping(monitor='loss', patience=50)
path = f'/models/2k22elo/checkpoints/'+pays+'10.h5'
mc_callback = tf.keras.callbacks.ModelCheckpoint(
          wd+path,
          verbose=0,
          save_weights_only=True,
          save_best_only=True)
ytraink = to_categorical(ytrain)
ytestk= to_categorical(ytest)
print(xtrain.shape, xtest.shape, ytraink.shape)
model.fit(xtrain, ytraink, epochs=600, validation_split=0.2, callbacks=[es_callback, mc_callback])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# (1026, 10) (114, 10) (1026, 2)
# Train on 820 samples, validate on 206 samples
# Epoch 1/600
# 672/820 [=======================>......] - ETA: 0s - loss: 3.4487 - accuracy: 0.5067
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2045: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 820/820 [==============================] - 1s 914us/sample - loss: 3.4665 - accuracy: 0.5159 - val_loss: 2.3785 - val_accuracy: 0.5801
# Epoch 2/600
# 820/820 [==============================] - 0s 377us/sample - loss: 2.9712 - accuracy: 0.5488 - val_loss: 1.5875 - val_accuracy: 0.5485
# Epoch 3/600
# 820/820 [==============================] - 0s 455us/sample - loss: 2.3359 - accuracy: 0.5518 - val_loss: 1.3296 - val_accuracy: 0.5607
# Epoch 4/600
# 820/820 [==============================] - 0s 462us/sample - loss: 1.9395 - accuracy: 0.5341 - val_loss: 0.7547 - val_accuracy: 0.5413
# Epoch 5/600
# 820/820 [==============================] - 0s 339us/sample - loss: 1.6595 - accuracy: 0.5335 - val_loss: 0.9188 - val_accuracy: 0.5510
# Epoch 6/600
# 820/820 [==============================] - 0s 297us/sample - loss: 1.7547 - accuracy: 0.5470 - val_loss: 0.8361 - val_accuracy: 0.5485
# Epoch 7/600
# 820/820 [==============================] - 0s 289us/sample - loss: 1.4150 - accuracy: 0.5372 - val_loss: 0.8148 - val_accuracy: 0.5316
# Epoch 8/600
# 820/820 [==============================] - 0s 319us/sample - loss: 1.1076 - accuracy: 0.5195 - val_loss: 0.8252 - val_accuracy: 0.5073
# Epoch 9/600
# 820/820 [==============================] - 0s 287us/sample - loss: 1.1022 - accuracy: 0.5341 - val_loss: 0.8122 - val_accuracy: 0.5073
# Epoch 10/600
# 820/820 [==============================] - 0s 279us/sample - loss: 0.9604 - accuracy: 0.5293 - val_loss: 0.8111 - val_accuracy: 0.5340
# Epoch 11/600
# 820/820 [==============================] - 0s 308us/sample - loss: 1.0644 - accuracy: 0.5409 - val_loss: 0.7908 - val_accuracy: 0.5364
# Epoch 12/600
# 820/820 [==============================] - 0s 310us/sample - loss: 1.0076 - accuracy: 0.5250 - val_loss: 0.8554 - val_accuracy: 0.5024
# Epoch 13/600
# 820/820 [==============================] - 0s 391us/sample - loss: 0.9182 - accuracy: 0.5341 - val_loss: 0.7421 - val_accuracy: 0.5388
# Epoch 14/600
# 820/820 [==============================] - 0s 365us/sample - loss: 0.9383 - accuracy: 0.5427 - val_loss: 0.7837 - val_accuracy: 0.5291
# Epoch 15/600
# 820/820 [==============================] - 0s 403us/sample - loss: 0.9098 - accuracy: 0.5415 - val_loss: 0.7719 - val_accuracy: 0.5340
# Epoch 16/600
# 820/820 [==============================] - 0s 375us/sample - loss: 0.9330 - accuracy: 0.5354 - val_loss: 0.7925 - val_accuracy: 0.5121
# Epoch 17/600
# 820/820 [==============================] - 0s 365us/sample - loss: 0.8765 - accuracy: 0.5354 - val_loss: 0.7475 - val_accuracy: 0.5340
# Epoch 18/600
# 820/820 [==============================] - 0s 395us/sample - loss: 0.8376 - accuracy: 0.5415 - val_loss: 0.7718 - val_accuracy: 0.5073
# Epoch 19/600
# 820/820 [==============================] - 0s 366us/sample - loss: 0.7975 - accuracy: 0.5390 - val_loss: 0.7528 - val_accuracy: 0.5000
# Epoch 20/600
# 820/820 [==============================] - 0s 341us/sample - loss: 0.7816 - accuracy: 0.5433 - val_loss: 0.7335 - val_accuracy: 0.5024
# Epoch 21/600
# 820/820 [==============================] - 0s 345us/sample - loss: 0.8194 - accuracy: 0.5421 - val_loss: 0.7150 - val_accuracy: 0.5121
# Epoch 22/600
# 820/820 [==============================] - 0s 376us/sample - loss: 0.8012 - accuracy: 0.5524 - val_loss: 0.7146 - val_accuracy: 0.5218
# Epoch 23/600
# 820/820 [==============================] - 0s 348us/sample - loss: 0.7926 - accuracy: 0.5555 - val_loss: 0.7032 - val_accuracy: 0.5340
# Epoch 24/600
# 820/820 [==============================] - 0s 318us/sample - loss: 0.8683 - accuracy: 0.5634 - val_loss: 0.7121 - val_accuracy: 0.5218
# Epoch 25/600
# 820/820 [==============================] - 0s 341us/sample - loss: 0.8284 - accuracy: 0.5482 - val_loss: 0.7013 - val_accuracy: 0.5364
# Epoch 26/600
# 820/820 [==============================] - 0s 371us/sample - loss: 0.8782 - accuracy: 0.5573 - val_loss: 0.6899 - val_accuracy: 0.5607
# Epoch 27/600
# 820/820 [==============================] - 0s 310us/sample - loss: 0.7818 - accuracy: 0.5622 - val_loss: 0.7099 - val_accuracy: 0.5267
# Epoch 28/600
# 820/820 [==============================] - 0s 295us/sample - loss: 0.7955 - accuracy: 0.5268 - val_loss: 0.7396 - val_accuracy: 0.5000
# Epoch 29/600
# 820/820 [==============================] - 0s 301us/sample - loss: 0.7875 - accuracy: 0.5183 - val_loss: 0.7221 - val_accuracy: 0.5000
# Epoch 30/600
# 820/820 [==============================] - 0s 316us/sample - loss: 0.7929 - accuracy: 0.5213 - val_loss: 0.7155 - val_accuracy: 0.5024
# Epoch 31/600
# 820/820 [==============================] - 0s 301us/sample - loss: 0.7715 - accuracy: 0.5274 - val_loss: 0.7079 - val_accuracy: 0.5049
# Epoch 32/600
# 820/820 [==============================] - 0s 295us/sample - loss: 0.7440 - accuracy: 0.5335 - val_loss: 0.6996 - val_accuracy: 0.4951
# Epoch 33/600
# 820/820 [==============================] - 0s 322us/sample - loss: 0.7383 - accuracy: 0.5268 - val_loss: 0.6916 - val_accuracy: 0.5000
# Epoch 34/600
# 820/820 [==============================] - 0s 348us/sample - loss: 0.7383 - accuracy: 0.5543 - val_loss: 0.6831 - val_accuracy: 0.5146
# Epoch 35/600
# 820/820 [==============================] - 0s 358us/sample - loss: 0.7455 - accuracy: 0.5598 - val_loss: 0.6721 - val_accuracy: 0.5655
# Epoch 36/600
# 820/820 [==============================] - 0s 311us/sample - loss: 0.7158 - accuracy: 0.5561 - val_loss: 0.6779 - val_accuracy: 0.5218
# Epoch 37/600
# 820/820 [==============================] - 0s 317us/sample - loss: 0.7027 - accuracy: 0.5598 - val_loss: 0.6754 - val_accuracy: 0.5631
# Epoch 38/600
# 820/820 [==============================] - 0s 408us/sample - loss: 0.6998 - accuracy: 0.5561 - val_loss: 0.6675 - val_accuracy: 0.5850
# Epoch 39/600
# 820/820 [==============================] - 0s 376us/sample - loss: 0.7346 - accuracy: 0.5762 - val_loss: 0.6685 - val_accuracy: 0.5825
# Epoch 40/600
# 820/820 [==============================] - 0s 457us/sample - loss: 0.7343 - accuracy: 0.5543 - val_loss: 0.6651 - val_accuracy: 0.5728
# Epoch 41/600
# 820/820 [==============================] - 0s 398us/sample - loss: 0.7571 - accuracy: 0.5640 - val_loss: 0.6644 - val_accuracy: 0.5631
# Epoch 42/600
# 820/820 [==============================] - 0s 329us/sample - loss: 0.7302 - accuracy: 0.5677 - val_loss: 0.6652 - val_accuracy: 0.5850
# Epoch 43/600
# 820/820 [==============================] - 0s 365us/sample - loss: 0.7392 - accuracy: 0.5634 - val_loss: 0.6638 - val_accuracy: 0.5874
# Epoch 44/600
# 820/820 [==============================] - 0s 336us/sample - loss: 0.7251 - accuracy: 0.5433 - val_loss: 0.6592 - val_accuracy: 0.5874
# Epoch 45/600
# 820/820 [==============================] - 0s 288us/sample - loss: 0.7216 - accuracy: 0.5713 - val_loss: 0.6652 - val_accuracy: 0.5607
# Epoch 46/600
# 820/820 [==============================] - 0s 295us/sample - loss: 0.7323 - accuracy: 0.5451 - val_loss: 0.6646 - val_accuracy: 0.5583
# Epoch 47/600
# 820/820 [==============================] - 0s 368us/sample - loss: 0.7348 - accuracy: 0.5561 - val_loss: 0.6585 - val_accuracy: 0.5728
# Epoch 48/600
# 820/820 [==============================] - 0s 338us/sample - loss: 0.7287 - accuracy: 0.5634 - val_loss: 0.6667 - val_accuracy: 0.5534
# Epoch 49/600
# 820/820 [==============================] - 0s 428us/sample - loss: 0.7179 - accuracy: 0.5549 - val_loss: 0.6576 - val_accuracy: 0.5752
# Epoch 50/600
# 820/820 [==============================] - 0s 456us/sample - loss: 0.6869 - accuracy: 0.5854 - val_loss: 0.6518 - val_accuracy: 0.5777
# Epoch 51/600
# 820/820 [==============================] - 0s 427us/sample - loss: 0.7513 - accuracy: 0.5768 - val_loss: 0.6416 - val_accuracy: 0.6092
# Epoch 52/600
# 820/820 [==============================] - 0s 381us/sample - loss: 0.7248 - accuracy: 0.5848 - val_loss: 0.6425 - val_accuracy: 0.6092
# Epoch 53/600
# 820/820 [==============================] - 0s 386us/sample - loss: 0.6824 - accuracy: 0.5872 - val_loss: 0.6500 - val_accuracy: 0.5825
# Epoch 54/600
# 820/820 [==============================] - 0s 371us/sample - loss: 0.7045 - accuracy: 0.5762 - val_loss: 0.6545 - val_accuracy: 0.5898
# Epoch 55/600
# 820/820 [==============================] - 0s 358us/sample - loss: 0.7063 - accuracy: 0.5726 - val_loss: 0.6453 - val_accuracy: 0.6311
# Epoch 56/600
# 820/820 [==============================] - 0s 406us/sample - loss: 0.6944 - accuracy: 0.5976 - val_loss: 0.6403 - val_accuracy: 0.6359
# Epoch 57/600
# 820/820 [==============================] - 0s 395us/sample - loss: 0.7119 - accuracy: 0.5780 - val_loss: 0.6636 - val_accuracy: 0.5631
# Epoch 58/600
# 820/820 [==============================] - 0s 312us/sample - loss: 0.7053 - accuracy: 0.5665 - val_loss: 0.6611 - val_accuracy: 0.5631
# Epoch 59/600
# 820/820 [==============================] - 0s 309us/sample - loss: 0.6916 - accuracy: 0.5872 - val_loss: 0.6435 - val_accuracy: 0.6238
# Epoch 60/600
# 820/820 [==============================] - 0s 393us/sample - loss: 0.7217 - accuracy: 0.5713 - val_loss: 0.6382 - val_accuracy: 0.6432
# Epoch 61/600
# 820/820 [==============================] - 0s 411us/sample - loss: 0.7331 - accuracy: 0.5756 - val_loss: 0.6327 - val_accuracy: 0.6383
# Epoch 62/600
# 820/820 [==============================] - 0s 401us/sample - loss: 0.7380 - accuracy: 0.5835 - val_loss: 0.6450 - val_accuracy: 0.6335
# Epoch 63/600
# 820/820 [==============================] - 0s 449us/sample - loss: 0.6967 - accuracy: 0.5793 - val_loss: 0.6618 - val_accuracy: 0.6286
# Epoch 64/600
# 820/820 [==============================] - 0s 327us/sample - loss: 0.7051 - accuracy: 0.5774 - val_loss: 0.6748 - val_accuracy: 0.5243
# Epoch 65/600
# 820/820 [==============================] - 0s 331us/sample - loss: 0.7152 - accuracy: 0.5390 - val_loss: 0.6751 - val_accuracy: 0.5267
# Epoch 66/600
# 820/820 [==============================] - 0s 299us/sample - loss: 0.7112 - accuracy: 0.5500 - val_loss: 0.6665 - val_accuracy: 0.5607
# Epoch 67/600
# 820/820 [==============================] - 0s 318us/sample - loss: 0.7222 - accuracy: 0.5457 - val_loss: 0.6593 - val_accuracy: 0.5801
# Epoch 68/600
# 820/820 [==============================] - 0s 314us/sample - loss: 0.7134 - accuracy: 0.5665 - val_loss: 0.6738 - val_accuracy: 0.5194
# Epoch 69/600
# 820/820 [==============================] - 0s 301us/sample - loss: 0.6920 - accuracy: 0.5470 - val_loss: 0.6549 - val_accuracy: 0.5485
# Epoch 70/600
# 820/820 [==============================] - 0s 294us/sample - loss: 0.7307 - accuracy: 0.5726 - val_loss: 0.6391 - val_accuracy: 0.5995
# Epoch 71/600
# 820/820 [==============================] - 0s 327us/sample - loss: 0.6993 - accuracy: 0.5872 - val_loss: 0.6479 - val_accuracy: 0.5850
# Epoch 72/600
# 820/820 [==============================] - 0s 291us/sample - loss: 0.7082 - accuracy: 0.5780 - val_loss: 0.6587 - val_accuracy: 0.5485
# Epoch 73/600
# 820/820 [==============================] - 0s 285us/sample - loss: 0.7039 - accuracy: 0.5829 - val_loss: 0.6529 - val_accuracy: 0.5583
# Epoch 74/600
# 820/820 [==============================] - 0s 309us/sample - loss: 0.7224 - accuracy: 0.5805 - val_loss: 0.6488 - val_accuracy: 0.5680
# Epoch 75/600
# 820/820 [==============================] - 0s 322us/sample - loss: 0.6957 - accuracy: 0.5799 - val_loss: 0.6375 - val_accuracy: 0.5922
# Epoch 76/600
# 820/820 [==============================] - 0s 317us/sample - loss: 0.6992 - accuracy: 0.5744 - val_loss: 0.6518 - val_accuracy: 0.5728
# Epoch 77/600
# 820/820 [==============================] - 0s 292us/sample - loss: 0.6797 - accuracy: 0.5866 - val_loss: 0.6435 - val_accuracy: 0.6262
# Epoch 78/600
# 820/820 [==============================] - 0s 295us/sample - loss: 0.6963 - accuracy: 0.5878 - val_loss: 0.6394 - val_accuracy: 0.6359
# Epoch 79/600
# 820/820 [==============================] - 0s 314us/sample - loss: 0.7277 - accuracy: 0.6116 - val_loss: 0.6509 - val_accuracy: 0.6505
# Epoch 80/600
# 820/820 [==============================] - 0s 309us/sample - loss: 0.7346 - accuracy: 0.5848 - val_loss: 0.6474 - val_accuracy: 0.6553
# Epoch 81/600
# 820/820 [==============================] - 0s 312us/sample - loss: 0.7222 - accuracy: 0.5750 - val_loss: 0.6442 - val_accuracy: 0.6335
# Epoch 82/600
# 820/820 [==============================] - 0s 287us/sample - loss: 0.7031 - accuracy: 0.5799 - val_loss: 0.6381 - val_accuracy: 0.6311
# Epoch 83/600
# 820/820 [==============================] - 0s 319us/sample - loss: 0.7254 - accuracy: 0.5896 - val_loss: 0.6492 - val_accuracy: 0.5510
# Epoch 84/600
# 820/820 [==============================] - 0s 308us/sample - loss: 0.7057 - accuracy: 0.5720 - val_loss: 0.6583 - val_accuracy: 0.5437
# Epoch 85/600
# 820/820 [==============================] - 0s 309us/sample - loss: 0.7535 - accuracy: 0.5488 - val_loss: 0.6733 - val_accuracy: 0.5388
# Epoch 86/600
# 820/820 [==============================] - 0s 310us/sample - loss: 0.7410 - accuracy: 0.5451 - val_loss: 0.6537 - val_accuracy: 0.5558
# Epoch 87/600
# 820/820 [==============================] - 0s 314us/sample - loss: 0.7473 - accuracy: 0.5695 - val_loss: 0.6458 - val_accuracy: 0.5558
# Epoch 88/600
# 820/820 [==============================] - 0s 323us/sample - loss: 0.7507 - accuracy: 0.5628 - val_loss: 0.6472 - val_accuracy: 0.5607
# Epoch 89/600
# 820/820 [==============================] - 0s 307us/sample - loss: 0.6965 - accuracy: 0.5787 - val_loss: 0.6416 - val_accuracy: 0.5655
# Epoch 90/600
# 820/820 [==============================] - 0s 303us/sample - loss: 0.6984 - accuracy: 0.5780 - val_loss: 0.6400 - val_accuracy: 0.5728
# Epoch 91/600
# 820/820 [==============================] - 0s 369us/sample - loss: 0.7538 - accuracy: 0.5988 - val_loss: 0.6316 - val_accuracy: 0.5850
# Epoch 92/600
# 820/820 [==============================] - 0s 344us/sample - loss: 0.7260 - accuracy: 0.5896 - val_loss: 0.6359 - val_accuracy: 0.5850
# Epoch 93/600
# 820/820 [==============================] - 0s 318us/sample - loss: 0.6636 - accuracy: 0.5939 - val_loss: 0.6444 - val_accuracy: 0.5850
# Epoch 94/600
# 820/820 [==============================] - 0s 322us/sample - loss: 0.6829 - accuracy: 0.5665 - val_loss: 0.6397 - val_accuracy: 0.6189
# Epoch 95/600
# 820/820 [==============================] - 0s 303us/sample - loss: 0.7093 - accuracy: 0.5854 - val_loss: 0.6621 - val_accuracy: 0.6165
# Epoch 96/600
# 820/820 [==============================] - 0s 352us/sample - loss: 0.7624 - accuracy: 0.5970 - val_loss: 0.6310 - val_accuracy: 0.5850
# Epoch 97/600
# 820/820 [==============================] - 0s 309us/sample - loss: 0.7434 - accuracy: 0.5780 - val_loss: 0.6394 - val_accuracy: 0.6238
# Epoch 98/600
# 820/820 [==============================] - 0s 319us/sample - loss: 0.6888 - accuracy: 0.5744 - val_loss: 0.6352 - val_accuracy: 0.6286
# Epoch 99/600
# 820/820 [==============================] - 0s 405us/sample - loss: 0.7354 - accuracy: 0.5890 - val_loss: 0.6292 - val_accuracy: 0.6335
# Epoch 100/600
# 820/820 [==============================] - 0s 396us/sample - loss: 0.7078 - accuracy: 0.6030 - val_loss: 0.6580 - val_accuracy: 0.6432
# Epoch 101/600
# 820/820 [==============================] - 0s 419us/sample - loss: 0.7350 - accuracy: 0.6037 - val_loss: 0.6317 - val_accuracy: 0.6408
# Epoch 102/600
# 820/820 [==============================] - 0s 430us/sample - loss: 0.7155 - accuracy: 0.6146 - val_loss: 0.6191 - val_accuracy: 0.6481
# Epoch 103/600
# 820/820 [==============================] - 0s 444us/sample - loss: 0.7952 - accuracy: 0.6104 - val_loss: 0.6173 - val_accuracy: 0.6505
# Epoch 104/600
# 820/820 [==============================] - 0s 462us/sample - loss: 0.7107 - accuracy: 0.6207 - val_loss: 0.6162 - val_accuracy: 0.6214
# Epoch 105/600
# 820/820 [==============================] - 0s 395us/sample - loss: 0.7069 - accuracy: 0.6165 - val_loss: 0.6252 - val_accuracy: 0.6481
# Epoch 106/600
# 820/820 [==============================] - 0s 382us/sample - loss: 0.6627 - accuracy: 0.5854 - val_loss: 0.6403 - val_accuracy: 0.6432
# Epoch 107/600
# 820/820 [==============================] - 0s 415us/sample - loss: 0.7061 - accuracy: 0.6134 - val_loss: 0.6345 - val_accuracy: 0.6262
# Epoch 108/600
# 820/820 [==============================] - 0s 321us/sample - loss: 0.7064 - accuracy: 0.6043 - val_loss: 0.6328 - val_accuracy: 0.6286
# Epoch 109/600
# 820/820 [==============================] - 0s 297us/sample - loss: 0.6667 - accuracy: 0.6256 - val_loss: 0.6294 - val_accuracy: 0.6481
# Epoch 110/600
# 820/820 [==============================] - 0s 335us/sample - loss: 0.7094 - accuracy: 0.6018 - val_loss: 0.6205 - val_accuracy: 0.6578
# Epoch 111/600
# 820/820 [==============================] - 0s 352us/sample - loss: 0.7301 - accuracy: 0.6177 - val_loss: 0.6211 - val_accuracy: 0.6723
# Epoch 112/600
# 820/820 [==============================] - 0s 398us/sample - loss: 0.7933 - accuracy: 0.6116 - val_loss: 0.6260 - val_accuracy: 0.6481
# Epoch 113/600
# 820/820 [==============================] - 0s 414us/sample - loss: 0.7529 - accuracy: 0.6250 - val_loss: 0.6520 - val_accuracy: 0.6505
# Epoch 114/600
# 820/820 [==============================] - 0s 401us/sample - loss: 0.6938 - accuracy: 0.6165 - val_loss: 0.6414 - val_accuracy: 0.6529
# Epoch 115/600
# 820/820 [==============================] - 0s 305us/sample - loss: 0.7022 - accuracy: 0.6152 - val_loss: 0.6371 - val_accuracy: 0.6262
# Epoch 116/600
# 820/820 [==============================] - 0s 326us/sample - loss: 0.6595 - accuracy: 0.6165 - val_loss: 0.6627 - val_accuracy: 0.6286
# Epoch 117/600
# 820/820 [==============================] - 0s 302us/sample - loss: 0.6621 - accuracy: 0.6067 - val_loss: 0.6189 - val_accuracy: 0.6432
# Epoch 118/600
# 820/820 [==============================] - 0s 336us/sample - loss: 0.7324 - accuracy: 0.6049 - val_loss: 0.6294 - val_accuracy: 0.6481
# Epoch 119/600
# 820/820 [==============================] - 0s 301us/sample - loss: 0.6436 - accuracy: 0.6238 - val_loss: 0.6395 - val_accuracy: 0.6529
# Epoch 120/600
# 820/820 [==============================] - 0s 315us/sample - loss: 0.6944 - accuracy: 0.6311 - val_loss: 0.6364 - val_accuracy: 0.6481
# Epoch 121/600
# 820/820 [==============================] - 0s 295us/sample - loss: 0.6841 - accuracy: 0.6354 - val_loss: 0.7060 - val_accuracy: 0.6456
# Epoch 122/600
# 820/820 [==============================] - 0s 331us/sample - loss: 0.6906 - accuracy: 0.6451 - val_loss: 0.7345 - val_accuracy: 0.6214
# Epoch 123/600
# 820/820 [==============================] - 0s 313us/sample - loss: 0.7742 - accuracy: 0.6390 - val_loss: 0.6914 - val_accuracy: 0.6311
# Epoch 124/600
# 820/820 [==============================] - 0s 301us/sample - loss: 0.7277 - accuracy: 0.6439 - val_loss: 0.6954 - val_accuracy: 0.6456
# Epoch 125/600
# 820/820 [==============================] - 0s 310us/sample - loss: 0.6661 - accuracy: 0.6159 - val_loss: 0.6879 - val_accuracy: 0.6117
# Epoch 126/600
# 820/820 [==============================] - 0s 308us/sample - loss: 0.7064 - accuracy: 0.6079 - val_loss: 0.6825 - val_accuracy: 0.6311
# Epoch 127/600
# 820/820 [==============================] - 0s 282us/sample - loss: 0.6706 - accuracy: 0.6226 - val_loss: 0.7112 - val_accuracy: 0.6335
# Epoch 128/600
# 820/820 [==============================] - 0s 307us/sample - loss: 0.6889 - accuracy: 0.6195 - val_loss: 0.7109 - val_accuracy: 0.6311
# Epoch 129/600
# 820/820 [==============================] - 0s 288us/sample - loss: 0.7022 - accuracy: 0.6384 - val_loss: 0.6788 - val_accuracy: 0.6335
# Epoch 130/600
# 820/820 [==============================] - 0s 342us/sample - loss: 0.6749 - accuracy: 0.6079 - val_loss: 0.6872 - val_accuracy: 0.6383
# Epoch 131/600
# 820/820 [==============================] - 0s 313us/sample - loss: 0.7072 - accuracy: 0.6171 - val_loss: 0.6806 - val_accuracy: 0.6359
# Epoch 132/600
# 820/820 [==============================] - 0s 317us/sample - loss: 0.6748 - accuracy: 0.6189 - val_loss: 0.6849 - val_accuracy: 0.6481
# Epoch 133/600
# 820/820 [==============================] - 0s 327us/sample - loss: 0.7502 - accuracy: 0.6293 - val_loss: 0.7490 - val_accuracy: 0.6456
# Epoch 134/600
# 820/820 [==============================] - 0s 317us/sample - loss: 0.7718 - accuracy: 0.6079 - val_loss: 0.6493 - val_accuracy: 0.6262
# Epoch 135/600
# 820/820 [==============================] - 0s 341us/sample - loss: 0.6698 - accuracy: 0.6116 - val_loss: 0.6424 - val_accuracy: 0.6311
# Epoch 136/600
# 820/820 [==============================] - 0s 336us/sample - loss: 0.7124 - accuracy: 0.6024 - val_loss: 0.6965 - val_accuracy: 0.6335
# Epoch 137/600
# 820/820 [==============================] - 0s 358us/sample - loss: 0.6823 - accuracy: 0.6220 - val_loss: 0.6675 - val_accuracy: 0.6408
# Epoch 138/600
# 820/820 [==============================] - 0s 413us/sample - loss: 0.7283 - accuracy: 0.6366 - val_loss: 0.6856 - val_accuracy: 0.6383
# Epoch 139/600
# 820/820 [==============================] - 0s 442us/sample - loss: 0.6997 - accuracy: 0.6189 - val_loss: 0.6629 - val_accuracy: 0.6311
# Epoch 140/600
# 820/820 [==============================] - 0s 407us/sample - loss: 0.6932 - accuracy: 0.6213 - val_loss: 0.6836 - val_accuracy: 0.6359
# Epoch 141/600
# 820/820 [==============================] - 0s 318us/sample - loss: 0.7130 - accuracy: 0.6616 - val_loss: 0.6942 - val_accuracy: 0.6383
# Epoch 142/600
# 820/820 [==============================] - 0s 319us/sample - loss: 0.7349 - accuracy: 0.6390 - val_loss: 0.6908 - val_accuracy: 0.6311
# Epoch 143/600
# 820/820 [==============================] - 0s 327us/sample - loss: 0.7266 - accuracy: 0.6183 - val_loss: 0.7552 - val_accuracy: 0.6335
# Epoch 144/600
# 820/820 [==============================] - 0s 382us/sample - loss: 0.7166 - accuracy: 0.6384 - val_loss: 0.7557 - val_accuracy: 0.6262
# Epoch 145/600
# 820/820 [==============================] - 0s 338us/sample - loss: 0.7086 - accuracy: 0.6226 - val_loss: 0.7929 - val_accuracy: 0.6286
# Epoch 146/600
# 820/820 [==============================] - 0s 487us/sample - loss: 0.7334 - accuracy: 0.5939 - val_loss: 0.6497 - val_accuracy: 0.6068
# Epoch 147/600
# 820/820 [==============================] - 0s 495us/sample - loss: 0.6769 - accuracy: 0.5738 - val_loss: 0.6533 - val_accuracy: 0.6165
# Epoch 148/600
# 820/820 [==============================] - 0s 477us/sample - loss: 0.6789 - accuracy: 0.5957 - val_loss: 0.6817 - val_accuracy: 0.6189
# Epoch 149/600
# 820/820 [==============================] - 0s 497us/sample - loss: 0.6625 - accuracy: 0.6085 - val_loss: 0.7205 - val_accuracy: 0.6383
# Epoch 150/600
# 820/820 [==============================] - 0s 479us/sample - loss: 0.7479 - accuracy: 0.6140 - val_loss: 0.6912 - val_accuracy: 0.6019
# Epoch 151/600
# 820/820 [==============================] - 0s 482us/sample - loss: 0.6813 - accuracy: 0.6165 - val_loss: 0.7572 - val_accuracy: 0.6165
# Epoch 152/600
# 820/820 [==============================] - 0s 484us/sample - loss: 0.7869 - accuracy: 0.6311 - val_loss: 0.6868 - val_accuracy: 0.6117
# Epoch 153/600
# 820/820 [==============================] - 0s 500us/sample - loss: 0.7086 - accuracy: 0.6116 - val_loss: 0.6835 - val_accuracy: 0.6359
# Epoch 154/600
# 820/820 [==============================] - 0s 467us/sample - loss: 0.7332 - accuracy: 0.6360 - val_loss: 0.6756 - val_accuracy: 0.6456
# Epoch 155/600
# 820/820 [==============================] - 1s 644us/sample - loss: 0.7137 - accuracy: 0.6305 - val_loss: 0.6848 - val_accuracy: 0.6578
# Epoch 156/600
# 820/820 [==============================] - 1s 688us/sample - loss: 0.6497 - accuracy: 0.6354 - val_loss: 0.6837 - val_accuracy: 0.6408
# Epoch 157/600
# 820/820 [==============================] - 0s 516us/sample - loss: 0.6815 - accuracy: 0.6384 - val_loss: 0.7213 - val_accuracy: 0.6359
# Epoch 158/600
# 820/820 [==============================] - 0s 433us/sample - loss: 0.6526 - accuracy: 0.6378 - val_loss: 0.7029 - val_accuracy: 0.6044
# Epoch 159/600
# 820/820 [==============================] - 0s 416us/sample - loss: 0.6603 - accuracy: 0.6195 - val_loss: 0.6855 - val_accuracy: 0.6019
# Epoch 160/600
# 820/820 [==============================] - 0s 335us/sample - loss: 0.6657 - accuracy: 0.6213 - val_loss: 0.7884 - val_accuracy: 0.6262
# Epoch 161/600
# 820/820 [==============================] - 0s 336us/sample - loss: 0.6390 - accuracy: 0.6311 - val_loss: 0.6859 - val_accuracy: 0.6189
# Epoch 162/600
# 820/820 [==============================] - 0s 315us/sample - loss: 0.7274 - accuracy: 0.6457 - val_loss: 0.8219 - val_accuracy: 0.6359
# Epoch 163/600
# 820/820 [==============================] - 0s 331us/sample - loss: 0.7001 - accuracy: 0.6518 - val_loss: 0.8673 - val_accuracy: 0.6383
# Epoch 164/600
# 820/820 [==============================] - 0s 315us/sample - loss: 0.7235 - accuracy: 0.6494 - val_loss: 0.7734 - val_accuracy: 0.6432
# Epoch 165/600
# 820/820 [==============================] - 0s 318us/sample - loss: 0.6401 - accuracy: 0.6409 - val_loss: 0.8401 - val_accuracy: 0.6408
# Epoch 166/600
# 820/820 [==============================] - 0s 309us/sample - loss: 0.7209 - accuracy: 0.6262 - val_loss: 0.6722 - val_accuracy: 0.6262
# Epoch 167/600
# 820/820 [==============================] - 0s 328us/sample - loss: 0.6367 - accuracy: 0.6079 - val_loss: 0.7434 - val_accuracy: 0.6481
# Epoch 168/600
# 820/820 [==============================] - 0s 305us/sample - loss: 0.6754 - accuracy: 0.6384 - val_loss: 0.7513 - val_accuracy: 0.6505
# Epoch 169/600
# 820/820 [==============================] - 0s 306us/sample - loss: 0.7187 - accuracy: 0.6433 - val_loss: 0.7521 - val_accuracy: 0.6505
# Epoch 170/600
# 820/820 [==============================] - 0s 321us/sample - loss: 0.6699 - accuracy: 0.6415 - val_loss: 0.9210 - val_accuracy: 0.6505
# Epoch 171/600
# 820/820 [==============================] - 0s 357us/sample - loss: 0.6489 - accuracy: 0.6707 - val_loss: 0.7909 - val_accuracy: 0.6650
# Epoch 172/600
# 820/820 [==============================] - 0s 336us/sample - loss: 0.7350 - accuracy: 0.6250 - val_loss: 0.6647 - val_accuracy: 0.6408
# Epoch 173/600
# 820/820 [==============================] - 0s 350us/sample - loss: 0.6802 - accuracy: 0.6335 - val_loss: 0.6542 - val_accuracy: 0.6578
# Epoch 174/600
# 820/820 [==============================] - 0s 348us/sample - loss: 0.6598 - accuracy: 0.6329 - val_loss: 0.6963 - val_accuracy: 0.6383
# Epoch 175/600
# 820/820 [==============================] - 0s 334us/sample - loss: 0.6461 - accuracy: 0.6244 - val_loss: 0.7606 - val_accuracy: 0.6505
# Epoch 176/600
# 820/820 [==============================] - 0s 320us/sample - loss: 0.6525 - accuracy: 0.6476 - val_loss: 0.7384 - val_accuracy: 0.6553
# Epoch 177/600
# 820/820 [==============================] - 0s 362us/sample - loss: 0.6942 - accuracy: 0.6390 - val_loss: 0.9505 - val_accuracy: 0.6214
# Epoch 178/600
# 820/820 [==============================] - 0s 493us/sample - loss: 0.6551 - accuracy: 0.6421 - val_loss: 0.7139 - val_accuracy: 0.6456
# Epoch 179/600
# 820/820 [==============================] - 0s 485us/sample - loss: 0.6446 - accuracy: 0.6598 - val_loss: 0.8539 - val_accuracy: 0.6481
# Epoch 180/600
# 820/820 [==============================] - 0s 482us/sample - loss: 0.6471 - accuracy: 0.6329 - val_loss: 0.6703 - val_accuracy: 0.6432
# Epoch 181/600
# 820/820 [==============================] - 0s 443us/sample - loss: 0.7064 - accuracy: 0.6250 - val_loss: 0.7558 - val_accuracy: 0.6529
# Epoch 182/600
# 820/820 [==============================] - 0s 445us/sample - loss: 0.6837 - accuracy: 0.6659 - val_loss: 0.6345 - val_accuracy: 0.6481
# Epoch 183/600
# 820/820 [==============================] - 0s 353us/sample - loss: 0.6664 - accuracy: 0.6530 - val_loss: 0.6743 - val_accuracy: 0.5971
# Epoch 184/600
# 820/820 [==============================] - 0s 326us/sample - loss: 0.6328 - accuracy: 0.6384 - val_loss: 0.6619 - val_accuracy: 0.6214
# Epoch 185/600
# 820/820 [==============================] - 0s 335us/sample - loss: 0.7149 - accuracy: 0.6305 - val_loss: 0.8336 - val_accuracy: 0.6311
# Epoch 186/600
# 820/820 [==============================] - 0s 415us/sample - loss: 0.6712 - accuracy: 0.6360 - val_loss: 0.8101 - val_accuracy: 0.5947
# Epoch 187/600
# 820/820 [==============================] - 0s 496us/sample - loss: 0.6613 - accuracy: 0.6305 - val_loss: 0.8672 - val_accuracy: 0.5995
# Epoch 188/600
# 820/820 [==============================] - 0s 435us/sample - loss: 0.6453 - accuracy: 0.6299 - val_loss: 1.1906 - val_accuracy: 0.6214
# Epoch 189/600
# 820/820 [==============================] - 0s 346us/sample - loss: 0.6669 - accuracy: 0.6451 - val_loss: 1.2006 - val_accuracy: 0.6383
# Epoch 190/600
# 820/820 [==============================] - 0s 343us/sample - loss: 0.6800 - accuracy: 0.6543 - val_loss: 0.7384 - val_accuracy: 0.6408
# Epoch 191/600
# 820/820 [==============================] - 0s 328us/sample - loss: 0.6767 - accuracy: 0.6396 - val_loss: 1.1547 - val_accuracy: 0.6553
# Epoch 192/600
# 820/820 [==============================] - 0s 363us/sample - loss: 0.6317 - accuracy: 0.6683 - val_loss: 1.0506 - val_accuracy: 0.6578
# Epoch 193/600
# 820/820 [==============================] - 0s 502us/sample - loss: 0.6622 - accuracy: 0.6451 - val_loss: 0.9088 - val_accuracy: 0.6456
# Epoch 194/600
# 820/820 [==============================] - 0s 446us/sample - loss: 0.6211 - accuracy: 0.6500 - val_loss: 1.0658 - val_accuracy: 0.6432
# Epoch 195/600
# 820/820 [==============================] - 0s 492us/sample - loss: 0.6418 - accuracy: 0.6354 - val_loss: 0.7765 - val_accuracy: 0.6602
# Epoch 196/600
# 820/820 [==============================] - 0s 470us/sample - loss: 0.6287 - accuracy: 0.6250 - val_loss: 0.7635 - val_accuracy: 0.6481
# Epoch 197/600
# 820/820 [==============================] - 0s 446us/sample - loss: 0.6590 - accuracy: 0.6470 - val_loss: 0.6955 - val_accuracy: 0.6553
# Epoch 198/600
# 820/820 [==============================] - 0s 472us/sample - loss: 0.6273 - accuracy: 0.6555 - val_loss: 1.0984 - val_accuracy: 0.6602
# Epoch 199/600
# 820/820 [==============================] - 0s 460us/sample - loss: 0.6410 - accuracy: 0.6555 - val_loss: 0.6845 - val_accuracy: 0.6505
# Epoch 200/600
# 820/820 [==============================] - 0s 446us/sample - loss: 0.6515 - accuracy: 0.6567 - val_loss: 0.8640 - val_accuracy: 0.6383
# Epoch 201/600
# 820/820 [==============================] - 0s 356us/sample - loss: 0.7158 - accuracy: 0.6585 - val_loss: 0.7559 - val_accuracy: 0.6359
# Epoch 202/600
# 820/820 [==============================] - 0s 337us/sample - loss: 0.6374 - accuracy: 0.6549 - val_loss: 0.6756 - val_accuracy: 0.6553
# Epoch 203/600
# 820/820 [==============================] - 0s 321us/sample - loss: 0.6454 - accuracy: 0.6476 - val_loss: 0.6817 - val_accuracy: 0.6505
# Epoch 204/600
# 820/820 [==============================] - 0s 354us/sample - loss: 0.5989 - accuracy: 0.6665 - val_loss: 0.7622 - val_accuracy: 0.6456
# Epoch 205/600
# 820/820 [==============================] - 0s 346us/sample - loss: 0.6614 - accuracy: 0.6524 - val_loss: 0.8215 - val_accuracy: 0.6408
# Epoch 206/600
# 820/820 [==============================] - 0s 342us/sample - loss: 0.6450 - accuracy: 0.6555 - val_loss: 0.8657 - val_accuracy: 0.6335
# Epoch 207/600
# 820/820 [==============================] - 0s 339us/sample - loss: 0.6360 - accuracy: 0.6518 - val_loss: 0.9554 - val_accuracy: 0.6286
# Epoch 208/600
# 820/820 [==============================] - 0s 345us/sample - loss: 0.6164 - accuracy: 0.6524 - val_loss: 0.8967 - val_accuracy: 0.6311
# Epoch 209/600
# 820/820 [==============================] - 0s 335us/sample - loss: 0.7305 - accuracy: 0.6530 - val_loss: 1.0111 - val_accuracy: 0.6286
# Epoch 210/600
# 820/820 [==============================] - 0s 329us/sample - loss: 0.6335 - accuracy: 0.6293 - val_loss: 0.9248 - val_accuracy: 0.6165
# Epoch 211/600
# 820/820 [==============================] - 0s 333us/sample - loss: 0.7201 - accuracy: 0.6561 - val_loss: 1.0444 - val_accuracy: 0.6262
# Epoch 212/600
# 820/820 [==============================] - 0s 348us/sample - loss: 0.6520 - accuracy: 0.6750 - val_loss: 1.0331 - val_accuracy: 0.6456
# Epoch 213/600
# 820/820 [==============================] - 0s 334us/sample - loss: 0.6240 - accuracy: 0.6738 - val_loss: 0.9630 - val_accuracy: 0.6650
# Epoch 214/600
# 820/820 [==============================] - 0s 327us/sample - loss: 0.6400 - accuracy: 0.6750 - val_loss: 1.4808 - val_accuracy: 0.6505
# Epoch 215/600
# 820/820 [==============================] - 0s 338us/sample - loss: 0.6193 - accuracy: 0.6573 - val_loss: 0.8097 - val_accuracy: 0.6359
# Epoch 216/600
# 820/820 [==============================] - 0s 329us/sample - loss: 0.6442 - accuracy: 0.6768 - val_loss: 1.3317 - val_accuracy: 0.6529
# Epoch 217/600
# 820/820 [==============================] - 0s 332us/sample - loss: 0.6808 - accuracy: 0.6671 - val_loss: 1.2310 - val_accuracy: 0.6311
# Epoch 218/600
# 820/820 [==============================] - 0s 341us/sample - loss: 0.6642 - accuracy: 0.6683 - val_loss: 0.8291 - val_accuracy: 0.6238
# Epoch 219/600
# 820/820 [==============================] - 0s 340us/sample - loss: 0.6166 - accuracy: 0.6427 - val_loss: 0.9044 - val_accuracy: 0.6335
# Epoch 220/600
# 820/820 [==============================] - 0s 310us/sample - loss: 0.6549 - accuracy: 0.6463 - val_loss: 0.9183 - val_accuracy: 0.6626
# Epoch 221/600
# 820/820 [==============================] - 0s 327us/sample - loss: 0.6882 - accuracy: 0.6799 - val_loss: 0.7782 - val_accuracy: 0.6529
# Epoch 222/600
# 820/820 [==============================] - 0s 403us/sample - loss: 0.7011 - accuracy: 0.6402 - val_loss: 0.7972 - val_accuracy: 0.6214
# Epoch 223/600
# 820/820 [==============================] - 0s 421us/sample - loss: 0.6940 - accuracy: 0.6280 - val_loss: 0.7801 - val_accuracy: 0.6481
# Epoch 224/600
# 820/820 [==============================] - 0s 409us/sample - loss: 0.6852 - accuracy: 0.6341 - val_loss: 1.0469 - val_accuracy: 0.6189
# Epoch 225/600
# 820/820 [==============================] - 0s 398us/sample - loss: 0.7415 - accuracy: 0.6409 - val_loss: 0.8929 - val_accuracy: 0.6335
# Epoch 226/600
# 820/820 [==============================] - 0s 408us/sample - loss: 0.7097 - accuracy: 0.6396 - val_loss: 0.7728 - val_accuracy: 0.6189
# Epoch 227/600
# 820/820 [==============================] - 0s 397us/sample - loss: 0.7080 - accuracy: 0.6390 - val_loss: 1.1065 - val_accuracy: 0.6165
# Epoch 228/600
# 820/820 [==============================] - 0s 332us/sample - loss: 0.7451 - accuracy: 0.6494 - val_loss: 0.9104 - val_accuracy: 0.6189
# Epoch 229/600
# 820/820 [==============================] - 0s 335us/sample - loss: 0.6545 - accuracy: 0.6341 - val_loss: 0.7602 - val_accuracy: 0.5971
# Epoch 230/600
# 820/820 [==============================] - 0s 312us/sample - loss: 0.6886 - accuracy: 0.6354 - val_loss: 0.7555 - val_accuracy: 0.6189
# Epoch 231/600
# 820/820 [==============================] - 0s 329us/sample - loss: 0.6554 - accuracy: 0.6604 - val_loss: 0.8273 - val_accuracy: 0.6432
# Epoch 232/600
# 820/820 [==============================] - 0s 391us/sample - loss: 0.7121 - accuracy: 0.6652 - val_loss: 0.8971 - val_accuracy: 0.6602
# Epoch 233/600
# 820/820 [==============================] - 0s 396us/sample - loss: 0.6496 - accuracy: 0.6591 - val_loss: 0.9115 - val_accuracy: 0.6481
# Epoch 234/600
# 820/820 [==============================] - 0s 418us/sample - loss: 0.6705 - accuracy: 0.6591 - val_loss: 0.9348 - val_accuracy: 0.6335
# Epoch 235/600
# 820/820 [==============================] - 0s 391us/sample - loss: 0.7378 - accuracy: 0.6939 - val_loss: 1.0330 - val_accuracy: 0.6578
# Epoch 236/600
# 820/820 [==============================] - 0s 405us/sample - loss: 0.7096 - accuracy: 0.6537 - val_loss: 0.9737 - val_accuracy: 0.6311
# Epoch 237/600
# 820/820 [==============================] - 0s 381us/sample - loss: 0.7272 - accuracy: 0.6537 - val_loss: 0.8933 - val_accuracy: 0.6553
# Epoch 238/600
# 820/820 [==============================] - 0s 321us/sample - loss: 0.6609 - accuracy: 0.6689 - val_loss: 0.9303 - val_accuracy: 0.6019
# Epoch 239/600
# 820/820 [==============================] - 0s 346us/sample - loss: 0.7957 - accuracy: 0.6171 - val_loss: 0.9474 - val_accuracy: 0.5898
# Epoch 240/600
# 820/820 [==============================] - 0s 314us/sample - loss: 0.6517 - accuracy: 0.6091 - val_loss: 0.7754 - val_accuracy: 0.6117
# Epoch 241/600
# 820/820 [==============================] - 0s 330us/sample - loss: 0.6416 - accuracy: 0.6311 - val_loss: 0.7727 - val_accuracy: 0.6262
# Epoch 242/600
# 820/820 [==============================] - 0s 428us/sample - loss: 0.6773 - accuracy: 0.6360 - val_loss: 0.7954 - val_accuracy: 0.6262
# Epoch 243/600
# 820/820 [==============================] - 0s 407us/sample - loss: 0.6298 - accuracy: 0.6579 - val_loss: 0.8024 - val_accuracy: 0.6141
# Epoch 244/600
# 820/820 [==============================] - 0s 405us/sample - loss: 0.6119 - accuracy: 0.6665 - val_loss: 0.9167 - val_accuracy: 0.6117
# Epoch 245/600
# 820/820 [==============================] - 0s 386us/sample - loss: 0.6053 - accuracy: 0.6756 - val_loss: 0.7986 - val_accuracy: 0.6286
# Epoch 246/600
# 820/820 [==============================] - 0s 430us/sample - loss: 0.7094 - accuracy: 0.6323 - val_loss: 0.6988 - val_accuracy: 0.6117
# Epoch 247/600
# 820/820 [==============================] - 0s 381us/sample - loss: 0.6798 - accuracy: 0.6354 - val_loss: 0.6956 - val_accuracy: 0.6165
# Epoch 248/600
# 820/820 [==============================] - 0s 304us/sample - loss: 0.6679 - accuracy: 0.6384 - val_loss: 0.7184 - val_accuracy: 0.6359
# Epoch 249/600
# 820/820 [==============================] - 0s 328us/sample - loss: 0.6383 - accuracy: 0.6323 - val_loss: 0.7070 - val_accuracy: 0.6238
# Epoch 250/600
# 820/820 [==============================] - 0s 314us/sample - loss: 0.6645 - accuracy: 0.6500 - val_loss: 0.6870 - val_accuracy: 0.6214
# Epoch 251/600
# 820/820 [==============================] - 0s 310us/sample - loss: 0.6607 - accuracy: 0.6622 - val_loss: 0.7246 - val_accuracy: 0.6286
# Epoch 252/600
# 820/820 [==============================] - 0s 426us/sample - loss: 0.6705 - accuracy: 0.6518 - val_loss: 0.7592 - val_accuracy: 0.6262
# Epoch 253/600
# 820/820 [==============================] - 0s 419us/sample - loss: 0.6903 - accuracy: 0.6366 - val_loss: 0.8061 - val_accuracy: 0.6335
# Epoch 254/600
# 820/820 [==============================] - 0s 411us/sample - loss: 0.6663 - accuracy: 0.6677 - val_loss: 0.8675 - val_accuracy: 0.6286

# %%
model.load_weights(wd+"models/2k22elo/checkpoints/"+pays+"10.h5")
pred_train= model.predict(xtrain)
scores = model.evaluate(xtrain, ytraink, verbose=0)
print('Accuracy on training data: {}% '.format(scores[1]*100))
scores2 = model.evaluate(xtest, ytestk, verbose=0)
print('Accuracy on test data: {}% '.format(scores2[1]*100))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2067: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Accuracy on training data: 65.6920075416565%
# Accuracy on test data: 61.84210777282715%

# %%
model.save(wd+'/models/2k22elo/'+pays+'10.h5')

# %% [markdown]
# # Results on unseen data ?

# %% [markdown]
# ## Preparing data

# %%
def argmax(iterable):
    return max(enumerate(iterable), key=lambda x: x[1])[0]

def double_chance(c1, c2):
    m1=c2/(c1+c2)

    return round(m1*c1, 2)

# %%
def home_or_dc(row):
    if row['FTR'] == 'H':
        val = 0
    else:
        val = 1
    return val

def exact_pred(row):
    if row['FTR'] == 'H':
        val = 0
    elif row['FTR'] == 'D':
        val = 1
    else:
        val = 2
    return val

# %%
data21 = pd.read_csv(wd+'/datasets/'+pays+'_21.csv')[common_cols]
xg21 = pd.read_csv(wd+'/datasets/'+pays+'21xG.csv')[['Squad', 'xG']]
data21["index"]=data21.apply(add_index, axis=1)
def custom_hs21(row):
  value = data21.loc[(data21['HomeTeam'] == row['HomeTeam'])].loc[data21['index']<int(row.name)]['HS'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_as21(row):
  value = data21.loc[(data21['AwayTeam'] == row['AwayTeam'])].loc[data21['index']<int(row.name)]['AS'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_hst21(row):
  value = data21.loc[(data21['HomeTeam'] == row['HomeTeam'])].loc[data21['index']<int(row.name)]['HST'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_ast21(row):
  value = data21.loc[(data21['AwayTeam'] == row['AwayTeam'])].loc[data21['index']<int(row.name)]['AST'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_hc21(row):
  value = data21.loc[(data21['HomeTeam'] == row['HomeTeam'])].loc[data21['index']<int(row.name)]['HC'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_ac21(row):
  value = data21.loc[(data21['AwayTeam'] == row['AwayTeam'])].loc[data21['index']<int(row.name)]['AC'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_hf21(row):
  value = data21.loc[(data21['HomeTeam'] == row['HomeTeam'])].loc[data21['index']<int(row.name)]['HF'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_af21(row):
  value = data21.loc[(data21['AwayTeam'] == row['AwayTeam'])].loc[data21['index']<int(row.name)]['AF'].mean()
  if math.isnan(value):
    return 0
  return value

def custom_psdg21(row):
  pshg = data21.loc[(data21['HomeTeam'] == row['HomeTeam'])].loc[data21['index']<int(row.name)]['FTHG'].sum()
  psag = data21.loc[(data21['AwayTeam'] == row['AwayTeam'])].loc[data21['index']<int(row.name)]['FTAG'].sum()
  if math.isnan(pshg-psag):
    return 0
  return pshg-psag

def xhg21(row):
  return xg21.loc[xg21['Squad']==row["HomeTeam"]]["xG"].mean()

def xag21(row):
  return xg21.loc[xg21['Squad']==row["AwayTeam"]]["xG"].mean()

data21['xHG'] = data21.apply(xhg21, axis=1)
data21['xAG'] = data21.apply(xag21, axis=1)
data21['CustomHS']=data21.apply(custom_hs21, axis=1)
data21['CustomAS']=data21.apply(custom_as21, axis=1)
data21['CustomHST']=data21.apply(custom_hst21, axis=1)
data21['CustomAST']=data21.apply(custom_ast21, axis=1)
data21['CustomPSDG']=data21.apply(custom_psdg21, axis=1)
data21['FTR2']=data21.apply(home_or_dc, axis=1)
data21.tail(10)
# Out:
#        HomeTeam  B365A  HS  HTAG  ... CustomHST  CustomAST  CustomPSDG  FTR2
# 220   Marseille   7.00  18     2  ...  4.272727   3.363636           3     0
# 221  St Etienne   2.62  27     1  ...  4.363636   3.700000          -4     0
# 222      Monaco   3.75  10     0  ...  4.363636   4.800000          13     0
# 223     Lorient   2.15   8     0  ...  2.900000   4.545455          -9     0
# 224        Nice   6.00   7     0  ...  4.545455   3.090909           6     1
# 225       Reims   3.50  16     0  ...  4.200000   3.400000          -4     0
# 226  Strasbourg   4.50  13     0  ...  4.636364   2.909091          14     0
# 227      Troyes   4.00   9     0  ...  3.545455   3.272727           1     1
# 228      Rennes   7.00  19     0  ...  5.909091   3.727273          12     0
# 229       Lille   1.85  10     3  ...  3.800000   4.454545          -5     1
#
# [10 rows x 26 columns]

# %%
x21=data21[real_columns]
y21= data21['FTR2'].values
x21.tail(3)
# Out:
#      B365H  B365D  B365A   xHG  ...   CustomAS  CustomHST  CustomAST  CustomPSDG
# 227    2.0    3.3   4.00  21.9  ...   9.000000   3.545455   3.272727           1
# 228    1.5    4.2   7.00  38.8  ...  10.090909   5.909091   3.727273          12
# 229    4.2    3.6   1.85  34.8  ...  13.363636   3.800000   4.454545          -5
#
# [3 rows x 10 columns]

# %% [markdown]
# ## Results

# %%
pred21 = model.predict(x21)
odds = [(round(1+0.1*k, 2), round(2+0.1*i, 2)) for k in range(3, 8) for i in range(10)]

def calc_gain(low_odd, high_odd):
  gain21 = 0
  cpt_paris=0
  cpt_reus= 0
  for prediction, res, donnee in zip(pred21, y21, x21.itertuples()):
    if (argmax(prediction)==0): #home team to win
      if low_odd<donnee[1]<high_odd:
        #on joue
        cpt_paris+=1
        if res==0:
          gain21+=donnee[1]-1
          cpt_reus+=1
        else:
          gain21-=1
    else:#double chance
      cotedc=double_chance(donnee[2], donnee[3])
      if (low_odd<cotedc<high_odd):
        cpt_paris+=1
        if res==1:
          gain21+=cotedc-1
          cpt_reus+=1
        else:
          gain21-=1
  return gain21, cpt_paris

for low_odd, high_odd in odds:
  print(low_odd, high_odd, calc_gain(low_odd, high_odd))
# Out:
# 1.3 2.0 (-5.359999999999998, 157)
# 1.3 2.1 (-5.179999999999999, 173)
# 1.3 2.2 (-3.8299999999999983, 178)
# 1.3 2.3 (-2.599999999999997, 179)
# 1.3 2.4 (-1.9999999999999973, 183)
# 1.3 2.5 (-1.9999999999999973, 183)
# 1.3 2.6 (-2.9999999999999973, 184)
# 1.3 2.7 (-2.9999999999999973, 184)
# 1.3 2.8 (-1.2499999999999973, 185)
# 1.3 2.9 (-1.2499999999999973, 185)
# 1.4 2.0 (-0.0699999999999994, 126)
# 1.4 2.1 (0.11000000000000032, 142)
# 1.4 2.2 (1.459999999999999, 147)
# 1.4 2.3 (2.6900000000000013, 148)
# 1.4 2.4 (3.290000000000001, 152)
# 1.4 2.5 (3.290000000000001, 152)
# 1.4 2.6 (2.290000000000001, 153)
# 1.4 2.7 (2.290000000000001, 153)
# 1.4 2.8 (4.040000000000001, 154)
# 1.4 2.9 (4.040000000000001, 154)
# 1.5 2.0 (-1.179999999999998, 92)
# 1.5 2.1 (-1.0, 108)
# 1.5 2.2 (0.3500000000000023, 113)
# 1.5 2.3 (1.580000000000001, 114)
# 1.5 2.4 (2.1800000000000024, 118)
# 1.5 2.5 (2.1800000000000024, 118)
# 1.5 2.6 (1.1800000000000024, 119)
# 1.5 2.7 (1.1800000000000024, 119)
# 1.5 2.8 (2.9300000000000024, 120)
# 1.5 2.9 (2.9300000000000024, 120)
# 1.6 2.0 (0.9600000000000009, 57)
# 1.6 2.1 (1.1400000000000015, 73)
# 1.6 2.2 (2.490000000000001, 78)
# 1.6 2.3 (3.719999999999996, 79)
# 1.6 2.4 (4.319999999999997, 83)
# 1.6 2.5 (4.319999999999997, 83)
# 1.6 2.6 (3.3199999999999976, 84)
# 1.6 2.7 (3.3199999999999976, 84)
# 1.6 2.8 (5.069999999999998, 85)
# 1.6 2.9 (5.069999999999998, 85)
# 1.7 2.0 (-1.2899999999999996, 36)
# 1.7 2.1 (-1.1099999999999999, 52)
# 1.7 2.2 (0.23999999999999932, 57)
# 1.7 2.3 (1.4699999999999998, 58)
# 1.7 2.4 (2.0699999999999994, 62)
# 1.7 2.5 (2.0699999999999994, 62)
# 1.7 2.6 (1.0699999999999994, 63)
# 1.7 2.7 (1.0699999999999994, 63)
# 1.7 2.8 (2.8199999999999994, 64)
# 1.7 2.9 (2.8199999999999994, 64)

# %%
model.save(wd+'/models/2k21xG4ans/italy.h5')

# %% [markdown]
# ## Better for damsopronos ? since 29/11 ?

# %%
dpfr = data21.tail(69)
x2911 = dpfr[real_columns]
y2911 = dpfr['FTR2'].values

# %%
#model = keras.models.load_model("/content/drive/MyDrive/Colab Notebooks/models/france.h5")
pred2911 = model.predict(x2911)


odds = [(round(1+0.1*k, 2), round(2+0.1*i, 2)) for k in range(3, 8) for i in range(10)]

def calc_gain(low_odd, high_odd):
  gain21 = 0
  cpt_paris=0
  cpt_reus= 0
  for prediction, res, donnee in zip(pred2911, y2911, x2911.itertuples()):
    if (argmax(prediction)==0): #home team to win
      if low_odd<donnee[1]<high_odd:
        #on joue
        cpt_paris+=1
        if res==0:
          gain21+=donnee[1]-1
          cpt_reus+=1
        else:
          gain21-=1
    else:#double chance
      cotedc=double_chance(donnee[2], donnee[3])
      if (low_odd<cotedc<high_odd):
        cpt_paris+=1
        if res==1:
          gain21+=cotedc-1
          cpt_reus+=1
        else:
          gain21-=1
  return gain21, cpt_paris

for low_odd, high_odd in odds:
  print(low_odd, high_odd, calc_gain(low_odd, high_odd))
# Out:
# 1.3 2.0 (-0.8199999999999994, 41)
# 1.3 2.1 (0.2400000000000011, 42)
# 1.3 2.2 (-0.6399999999999992, 45)
# 1.3 2.3 (0.5700000000000012, 46)
# 1.3 2.4 (1.9400000000000013, 47)
# 1.3 2.5 (0.9400000000000013, 48)
# 1.3 2.6 (0.9400000000000013, 48)
# 1.3 2.7 (-0.05999999999999872, 49)
# 1.3 2.8 (-0.05999999999999872, 49)
# 1.3 2.9 (1.6000000000000014, 53)
# 1.4 2.0 (-1.3499999999999996, 32)
# 1.4 2.1 (-0.2899999999999996, 33)
# 1.4 2.2 (-1.1699999999999993, 36)
# 1.4 2.3 (0.04000000000000048, 37)
# 1.4 2.4 (1.4100000000000006, 38)
# 1.4 2.5 (0.4100000000000006, 39)
# 1.4 2.6 (0.4100000000000006, 39)
# 1.4 2.7 (-0.5899999999999994, 40)
# 1.4 2.8 (-0.5899999999999994, 40)
# 1.4 2.9 (1.0700000000000007, 44)
# 1.5 2.0 (-1.6399999999999992, 25)
# 1.5 2.1 (-0.5799999999999992, 26)
# 1.5 2.2 (-1.4599999999999993, 29)
# 1.5 2.3 (-0.2499999999999989, 30)
# 1.5 2.4 (1.120000000000001, 31)
# 1.5 2.5 (0.120000000000001, 32)
# 1.5 2.6 (0.120000000000001, 32)
# 1.5 2.7 (-0.879999999999999, 33)
# 1.5 2.8 (-0.879999999999999, 33)
# 1.5 2.9 (0.7800000000000016, 37)
# 1.6 2.0 (-2.9699999999999998, 17)
# 1.6 2.1 (-1.9099999999999997, 18)
# 1.6 2.2 (-2.7899999999999996, 21)
# 1.6 2.3 (-1.5799999999999996, 22)
# 1.6 2.4 (-0.20999999999999952, 23)
# 1.6 2.5 (-1.2099999999999995, 24)
# 1.6 2.6 (-1.2099999999999995, 24)
# 1.6 2.7 (-2.2099999999999995, 25)
# 1.6 2.8 (-2.2099999999999995, 25)
# 1.6 2.9 (-0.5499999999999985, 29)
# 1.7 2.0 (-1.87, 11)
# 1.7 2.1 (-0.81, 12)
# 1.7 2.2 (-1.6899999999999995, 15)
# 1.7 2.3 (-0.47999999999999954, 16)
# 1.7 2.4 (0.8900000000000001, 17)
# 1.7 2.5 (-0.10999999999999988, 18)
# 1.7 2.6 (-0.10999999999999988, 18)
# 1.7 2.7 (-1.1099999999999999, 19)
# 1.7 2.8 (-1.1099999999999999, 19)
# 1.7 2.9 (0.5500000000000003, 23)
